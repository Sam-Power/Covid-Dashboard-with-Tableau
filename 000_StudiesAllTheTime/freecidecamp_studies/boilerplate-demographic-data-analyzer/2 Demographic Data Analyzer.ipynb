# %%
import pandas as pd

# %%
df = pd.read_csv('adult.data.csv')
df.head()
# Out:
#    age         workclass  fnlwgt  education  education-num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 2   38           Private  215646    HS-grad              9
# 3   53           Private  234721       11th              7
# 4   28           Private  338409  Bachelors             13
#
#        marital-status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital-gain  capital-loss  hours-per-week native-country salary
# 0          2174             0              40  United-States  <=50K
# ...

# %%
df['race'].value_counts(dropna=False)
# Out:
# White                 27816
# Black                  3124
# Asian-Pac-Islander     1039
# Amer-Indian-Eskimo      311
# Other                   271
# Name: race, dtype: int64

# %%
round(df[df['sex']=='Male']['age'].mean(),1)
# Out:
# 39.4

# %%
len(df['education'])
# Out:
# 32561

# %%
round(df['education'].value_counts()['Bachelors'] / len(df['education']) *100,1)
# Out:
# 16.4

# %%
df[(df['education'] == 'Bachelors') | (df['education'] == 'Masters') |
   (df['education'] == 'Doctorate')]
# Out:
#        age         workclass  fnlwgt  education  education-num  \
# 0       39         State-gov   77516  Bachelors             13
# 1       50  Self-emp-not-inc   83311  Bachelors             13
# 4       28           Private  338409  Bachelors             13
# 5       37           Private  284582    Masters             14
# 8       31           Private   45781    Masters             14
# ...    ...               ...     ...        ...            ...
# 32538   38           Private  139180  Bachelors             13
# 32539   71                 ?  287372  Doctorate             16
# 32544   31           Private  199655    Masters             14
# 32553   32           Private  116138    Masters             14
# 32554   53           Private  321865    Masters             14
#
#            marital-status       occupation   relationship                race  \
# 0           Never-married     Adm-clerical  Not-in-family               White
# ...

# %%
a = df[(df['education'] == 'Bachelors') | (df['education'] == 'Masters') |
   (df['education'] == 'Doctorate')]
round(len(a[a['salary'] == '>50K']) / len(a) *100,1)
# Out:
# 46.5

# %%
b = df[(df['education'] != 'Bachelors') & (df['education'] != 'Masters') &
   (df['education'] != 'Doctorate')]
round(len(b[b['salary'] == '>50K']) / len(b) *100,1)
# Out:
# 17.4

# %%
df['hours-per-week'].min()
# Out:
# 1

# %%
min_df = df[df['hours-per-week'] == df['hours-per-week'].min()]
int(len(min_df[min_df['salary']=='>50K']) / len(min_df) *100)
# Out:
# 10

# %%
df.groupby(by=df['native-country'])['salary'].value_counts()
# Out:
# native-country  salary
# ?               <=50K      437
#                 >50K       146
# Cambodia        <=50K       12
#                 >50K         7
# Canada          <=50K       82
#                           ...
# United-States   >50K      7171
# Vietnam         <=50K       62
#                 >50K         5
# Yugoslavia      <=50K       10
#                 >50K         6
# Name: salary, Length: 82, dtype: int64

# %%
df['c'] = 1
df
# Out:
#        age         workclass  fnlwgt   education  education-num  \
# 0       39         State-gov   77516   Bachelors             13
# 1       50  Self-emp-not-inc   83311   Bachelors             13
# 2       38           Private  215646     HS-grad              9
# 3       53           Private  234721        11th              7
# 4       28           Private  338409   Bachelors             13
# ...    ...               ...     ...         ...            ...
# 32556   27           Private  257302  Assoc-acdm             12
# 32557   40           Private  154374     HS-grad              9
# 32558   58           Private  151910     HS-grad              9
# 32559   22           Private  201490     HS-grad              9
# 32560   52      Self-emp-inc  287927     HS-grad              9
#
#            marital-status         occupation   relationship   race     sex  \
# 0           Never-married       Adm-clerical  Not-in-family  White    Male
# ...

# %%
df.pivot_table(index = df['native-country'], columns = df['salary'], values = df['c'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-75-f4b95b4e59f3> in <module>
# ----> 1 df.pivot_table(index = df['native-country'], columns = df['salary'], values = df['c'])
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in pivot_table(self, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed)
#    6824         from pandas.core.reshape.pivot import pivot_table
#    6825
# -> 6826         return pivot_table(
#    6827             self,
#    6828             values=values,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/reshape/pivot.py in pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed)
#      86         for i in values:
#      87             if i not in data:
# ---> 88                 raise KeyError(i)
#      89
# ...

# %%
df.groupby(by=['native-country','salary'])['salary'].value_counts()
# Out:
# native-country  salary  salary
# ?               <=50K   <=50K      437
#                 >50K    >50K       146
# Cambodia        <=50K   <=50K       12
#                 >50K    >50K         7
# Canada          <=50K   <=50K       82
#                                   ...
# United-States   >50K    >50K      7171
# Vietnam         <=50K   <=50K       62
#                 >50K    >50K         5
# Yugoslavia      <=50K   <=50K       10
#                 >50K    >50K         6
# Name: salary, Length: 82, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
group1 = df.groupby(['native-country', 'salary']).agg({'salary': 'count'})
pct = group1.groupby(level=0).apply(lambda x: 100 * x / float(x.sum()))
pct.columns = ['perc']

# %%
df2 = pd.DataFrame(pct)
df2 = df2.reset_index()

# %%
df2[(df2['salary']=='>50K')  & (df2['perc'] > 40)]
# Out:
#    native-country salary       perc
# 21         France   >50K  41.379310
# 40           Iran   >50K  41.860465

# %%
c = df2[(df2['salary']=='>50K')]
c
# Out:
#         native-country salary       perc
# 1                    ?   >50K  25.042882
# 3             Cambodia   >50K  36.842105
# 5               Canada   >50K  32.231405
# 7                China   >50K  26.666667
# 9             Columbia   >50K   3.389831
# 11                Cuba   >50K  26.315789
# 13  Dominican-Republic   >50K   2.857143
# 15             Ecuador   >50K  14.285714
# 17         El-Salvador   >50K   8.490566
# 19             England   >50K  33.333333
# 21              France   >50K  41.379310
# 23             Germany   >50K  32.116788
# 25              Greece   >50K  27.586207
# 27           Guatemala   >50K   4.687500
# 29               Haiti   >50K   9.090909
# 32            Honduras   >50K   7.692308
# 34                Hong   >50K  30.000000
# 36             Hungary   >50K  23.076923
# 38               India   >50K  40.000000
# 40                Iran   >50K  41.860465
# 42             Ireland   >50K  20.833333
# 44               Italy   >50K  34.246575
# ...

# %%
c[c['perc'] == c['perc'].max()]
# Out:
#    native-country salary       perc
# 40           Iran   >50K  41.860465

# %%
c[c['perc'] == c['perc'].max()]['native-country'].values[0]
# Out:
# 'Iran'

# %%
group1 = df.groupby(['native-country', 'salary']).agg({'salary': 'count'})
pct = group1.groupby(level=0).apply(lambda x: 100 * x / float(x.sum()))
pct.columns = ['perc']
df2 = pd.DataFrame(pct)
df2 = df2.reset_index()
c = df2[(df2['salary']=='>50K')]

c[c['perc'] == c['perc'].max()]['native-country'].values[0]
# Out:
# 'Iran'

# %%
round(c[c['perc'] == c['perc'].max()]['perc'].values[0],1)
# Out:
# 41.9

# %%
df_india_above_50 = df[ (df['native-country']=='India') & (df['salary'] == '>50K') ]
df_india_above_50['occupation'].value_counts().index[0]
# Out:
# 'Prof-specialty'
